# %%
import pandas as pd
df = pd.read_csv("data/heetch.csv")
df.columns
p1 = Point(24.952242, 60.1696017)

# %%
from shapely.geometry import Point, Polygon

df["point"] = df.apply(lambda x: Point(x["Origin Latitude"],x["Origin Longitude"]), axis=1)

# %%
df["lol"] = df.apply(lambda x: Point(x["Origin Latitude"],x["Origin Longitude"]), axis=1)

# %%
df["lol"].apply(lambda x: p1.contains(x)
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 101038    False
# 101039    False
# 101040    False
# 101041    False
# 101042    False
# Name: lol, Length: 101043, dtype: bool

# %%
df.loc[df["lol"].apply(lambda x: p1.contains(x) != True),"test"] = "TOP"

# %%
df
# Out:
#                  Created At  Driver Id  Estimated Approach Duration  \
# 0       2019-10-20 18:55:00  1000007.0                        180.0
# 1        2019-10-23 1:22:59  1000007.0                        240.0
# 2        2019-10-22 0:28:04  1000007.0                        120.0
# 3        2019-10-23 0:26:15  1000007.0                        360.0
# 4        2019-10-22 0:13:19  1000007.0                        240.0
# ...                     ...        ...                          ...
# 101038  2019-10-19 18:20:48        NaN                          NaN
# 101039  2019-10-19 19:44:03        NaN                          NaN
# 101040  2019-10-23 19:11:42        NaN                          NaN
# 101041  2019-10-20 20:03:48        NaN                          NaN
# 101042  2019-10-21 18:40:23        NaN                          NaN
#
#         Estimated Price                                    Id  \
# 0                    11  0edc6f9d-08a6-4e08-96cb-028bb8face34
# ...
